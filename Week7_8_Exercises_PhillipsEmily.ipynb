# %%
#importing required libraries
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
#reading in data candy csv
data_candy_df = pd.read_csv("Week7_8/candyhierarchy2017.csv")
data_candy_df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %% [markdown]
# # Describing the Data

# %%
#checking the dimensions of the table
print("The dimension of the table is: ", data_candy_df.shape)
print("2460 rows and 120 columns")
# Out:
# The dimension of the table is:  (2460, 120)
# 2460 rows and 120 columns

# %%
#looking at the types of variables
print("Describe Data")
print(data_candy_df.describe())
print("\nSummarized Data")
print(data_candy_df.describe(include=['O']))
# Out:
# Describe Data
#         Internal ID  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# count  2.460000e+03                     85.0                1362.0
# mean   9.028016e+07                      1.0                   1.0
# std    7.435532e+03                      0.0                   0.0
# min    9.025877e+07                      1.0                   1.0
# 25%    9.027520e+07                      1.0                   1.0
# 50%    9.027780e+07                      1.0                   1.0
# 75%    9.028242e+07                      1.0                   1.0
# max    9.031480e+07                      1.0                   1.0
#
#        Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo]
# count               99.0                67.0
# mean                 1.0                 1.0
# std                  0.0                 0.0
# min                  1.0                 1.0
# 25%                  1.0                 1.0
# 50%                  1.0                 1.0
# ...

# %%
#finding data types of variables in table
print(data_candy_df.dtypes)
# Out:
# Internal ID                   int64
# Q1: GOING OUT?               object
# Q2: GENDER                   object
# Q3: AGE                      object
# Q4: COUNTRY                  object
#                              ...
# Q12: MEDIA [Daily Dish]     float64
# Q12: MEDIA [Science]        float64
# Q12: MEDIA [ESPN]           float64
# Q12: MEDIA [Yahoo]          float64
# Click Coordinates (x, y)     object
# Length: 120, dtype: object

# %%
#checking unique values in each column
for col in data_candy_df:
    print(col + ": "+ str(data_candy_df[col].unique()) + "\n")
# Out:
# Internal ID: [90258773 90272821 90272829 ... 90314634 90314658 90314802]
#
# Q1: GOING OUT?: [nan 'No' 'Yes']
#
# Q2: GENDER: [nan 'Male' 'Female' "I'd rather not say" 'Other']
#
# Q3: AGE: [nan '44' '49' '40' '23' '53' '33' '43' '56' '64' '37' '59' '48' '54' '36'
#  '45' '25' '34' '35' '38' '58' '50' '47' '16' '52' '63' '65' '41' '27'
#  '31' '61' '46' '42' '62' '29' '39' '32' '28' '69' '67' '30' '22' '26'
#  '51' '70' '24' '18' '19' 'Old enough' '57' '60' '66' '12' 'Many' '55'
#  '72' '?' '21' '11' 'no' '9' '68' '20' '6' '10' '71' '90' '13' '45-55'
#  '312' '99' '7' 'hahahahaha' '88' '39.4' '74' '102' 'older than dirt' '17'
#  '15' '8' '75' '5u' 'Enough' 'See question 2' '24-50' '14' 'Over 50' '100'
#  '76' '1000' 'sixty-nine' '46 Halloweens.' 'ancient' '77' 'OLD' 'old' '73'
#  '70 1/2' '1' 'MY NAME JEFF' '4' '59 on the day after Halloween'
#  'old enough' 'your mom'
#  'I can remember when Java was a cool new language' '60+']
#
# ...

# %% [markdown]
# # Checking Missing Data

# %%
#looking for columns where data is missing
data_candy_df.columns[data_candy_df.isnull().any()]
# Out:
# Index(['Q1: GOING OUT?', 'Q2: GENDER', 'Q3: AGE', 'Q4: COUNTRY',
#        'Q5: STATE, PROVINCE, COUNTY, ETC', 'Q6 | 100 Grand Bar',
#        'Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)',
#        'Q6 | Any full-sized candy bar', 'Q6 | Black Jacks',
#        'Q6 | Bonkers (the candy)',
#        ...
#        'Q8: DESPAIR OTHER', 'Q9: OTHER COMMENTS', 'Q10: DRESS', 'Unnamed: 113',
#        'Q11: DAY', 'Q12: MEDIA [Daily Dish]', 'Q12: MEDIA [Science]',
#        'Q12: MEDIA [ESPN]', 'Q12: MEDIA [Yahoo]', 'Click Coordinates (x, y)'],
#       dtype='object', length=119)

# %%
#finding how many columns have missing data
data_candy_df.columns[data_candy_df.isnull().any()].shape
print("119 columns out of the total 120 columns have missing data")
# Out:
# 119 columns out of the total 120 columns have missing data

# %%
data_candy_df.isnull().sum()
# Out:
# Internal ID                    0
# Q1: GOING OUT?               110
# Q2: GENDER                    41
# Q3: AGE                       84
# Q4: COUNTRY                   64
#                             ...
# Q12: MEDIA [Daily Dish]     2375
# Q12: MEDIA [Science]        1098
# Q12: MEDIA [ESPN]           2361
# Q12: MEDIA [Yahoo]          2393
# Click Coordinates (x, y)     855
# Length: 120, dtype: int64

# %% [markdown]
# # Filling Missing Data

# %%
#using the fillna ffill method to fill missing data in with previous valid observation in the same column
data_candy_df = data_candy_df.fillna(method='ffill')

# %%
#dropping first row in the dataframe as it contains mostly missing values
data_candy_df = data_candy_df.iloc[1:,:]

# %%
#checking for columns with any missing data again
print("Columns with missing data:\n" + str(data_candy_df.columns[data_candy_df.isnull().any()]))
print("5 columns are still missing data")
# Out:
# Columns with missing data:
# Index(['Q8: DESPAIR OTHER', 'Unnamed: 113', 'Q12: MEDIA [Daily Dish]',
#        'Q12: MEDIA [ESPN]', 'Q12: MEDIA [Yahoo]'],
#       dtype='object')
# 5 columns are still missing data

# %% [markdown]
# # Filter Out Missing Data

# %%
#dropping the 5 columns which still have missing data 
data_candy_df = data_candy_df.dropna(axis=1)

# %%
data_candy_df.shape
print("2459 rows and 115 columns")
print("5 columns have been dropped for having missing data")
# Out:
# 2459 rows and 115 columns
# 5 columns have been dropped for having missing data

# %% [markdown]
# # Looking at Indices

# %%
data_candy_df.index
# Out:
# RangeIndex(start=1, stop=2460, step=1)

# %%
data_candy_df.columns
# Out:
# Index(['Internal ID', 'Q1: GOING OUT?', 'Q2: GENDER', 'Q3: AGE', 'Q4: COUNTRY',
#        'Q5: STATE, PROVINCE, COUNTY, ETC', 'Q6 | 100 Grand Bar',
#        'Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)',
#        'Q6 | Any full-sized candy bar', 'Q6 | Black Jacks',
#        ...
#        'Q6 | Whatchamacallit Bars', 'Q6 | White Bread',
#        'Q6 | Whole Wheat anything', 'Q6 | York Peppermint Patties',
#        'Q7: JOY OTHER', 'Q9: OTHER COMMENTS', 'Q10: DRESS', 'Q11: DAY',
#        'Q12: MEDIA [Science]', 'Click Coordinates (x, y)'],
#       dtype='object', length=115)

# %% [markdown]
# # Hierarchical Indexing

# %%
#setting the descriptive fields in the dataframe as the indices
#ID, Gender, Age, Country and State
multi = data_candy_df.set_index(['Internal ID','Q2: GENDER','Q3: AGE','Q4: COUNTRY','Q5: STATE, PROVINCE, COUNTY, ETC'])

# %%
multi.head()
# Out:
#                                                                             Q1: GOING OUT?  \
# Internal ID Q2: GENDER Q3: AGE Q4: COUNTRY Q5: STATE, PROVINCE, COUNTY, ETC
# 90272821    Male       44      USA         NM                                           No
# 90272829    Male       49      USA         Virginia                                     No
# 90272840    Male       40      us          or                                           No
# 90272841    Male       23      usa         exton pa                                     No
# 90272852    Male       23      usa         exton pa                                     No
#
#                                                                             Q6 | 100 Grand Bar  \
# Internal ID Q2: GENDER Q3: AGE Q4: COUNTRY Q5: STATE, PROVINCE, COUNTY, ETC
# 90272821    Male       44      USA         NM                                              MEH
# ...

# %% [markdown]
# The dataframe is now indexed by the variables which define each questionaire which are: ID, gender, age, country and state/provice/county. These will help us identify each record, and give more understanding to each row in terms of survey responses.

# %%
multi.index.names
# Out:
# FrozenList(['Internal ID', 'Q2: GENDER', 'Q3: AGE', 'Q4: COUNTRY', 'Q5: STATE, PROVINCE, COUNTY, ETC'])

# %% [markdown]
# # Reshape

# %%
#now that indices have been set, we can use the stack() method to pivot the columns into rows
result = multi.stack()

# %%
result
# Out:
# Internal ID  Q2: GENDER  Q3: AGE  Q4: COUNTRY  Q5: STATE, PROVINCE, COUNTY, ETC
# 90272821     Male        44       USA          NM                                Q1: GOING OUT?                                                                                                                           No
#                                                                                  Q6 | 100 Grand Bar                                                                                                                      MEH
#                                                                                  Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)                                              DESPAIR
#                                                                                  Q6 | Any full-sized candy bar                                                                                                           JOY
# ...

# %% [markdown]
# By pivoting the dataframe's columns into rows, it produces a Series where each group pertains to the survey responses for each respondent based on their ID, gender, age, country and state/province/county.
#
# It helps organize all of the data, and gives a better idea of the responses individually.

# %% [markdown]
# # Other Dataset

# %%
#MetObjects csv file -- > read into df
met_objects = pd.read_csv("Week7_8/MetObjects.csv")
met_objects.head()
# Out:
#   Object Number Is Highlight Is Public Domain Object ID         Department  \
# 0    1979.486.1        FALSE            FALSE         1  The American Wing
# 1    1980.264.5        FALSE            FALSE         2  The American Wing
# 2      67.265.9        FALSE            FALSE         3  The American Wing
# 3     67.265.10        FALSE            FALSE         4  The American Wing
# 4     67.265.11        FALSE            FALSE         5  The American Wing
#
#   Object Name                         Title Culture Period Dynasty  ...  \
# 0        Coin  One-dollar Liberty Head Coin     NaN    NaN     NaN  ...
# 1        Coin  Ten-dollar Liberty Head Coin     NaN    NaN     NaN  ...
# 2        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
# 3        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
# 4        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
#
#   Locale Locus Excavation River Classification Rights and Reproduction  \
# ...

# %%
met_objects.shape
# Out:
# (12108, 44)

# %%
met_objects.dtypes
# Out:
# Object Number               object
# Is Highlight                object
# Is Public Domain            object
# Object ID                   object
# Department                  object
# Object Name                 object
# Title                       object
# Culture                     object
# Period                      object
# Dynasty                     object
# Reign                       object
# Portfolio                   object
# Artist Role                 object
# Artist Prefix               object
# Artist Display Name         object
# Artist Display Bio          object
# Artist Suffix               object
# Artist Alpha Sort           object
# Artist Nationality          object
# Artist Begin Date           object
# Artist End Date             object
# Object Date                 object
# Object Begin Date           object
# Object End Date             object
# Medium                      object
# Dimensions                  object
# Credit Line                 object
# ...

# %% [markdown]
# # Dropping Missing & Duplicates

# %%
#drop any rows with all missing data
met_objects = met_objects.dropna(how='all')

# %%
print(met_objects.shape)
print("21 rows dropped for having all NA values")
# Out:
# (12087, 44)
# 21 rows dropped for having all NA values

# %%
#drop any columns with all missing data
met_objects = met_objects.dropna(axis=1,how='all')

# %%
print(met_objects.shape)
print("3 columns dropped")
# Out:
# (12087, 41)
# 3 columns dropped

# %%
#dropping duplicates
met_objects = met_objects.drop_duplicates()

# %%
print(met_objects.shape)
print("165 duplicate rows dropped")
# Out:
# (11922, 41)
# 165 duplicate rows dropped

# %% [markdown]
# # Split/Apply/Combine

# %% [markdown]
# #### Split

# %%
#split the data into groups
#each group is the set of objects in each department
df_by_department = met_objects.groupby('Department')
df_by_department.head()
# Out:
#                                            Object Number  \
# 0                                             1979.486.1
# 1                                             1980.264.5
# 2                                               67.265.9
# 3                                              67.265.10
# 4                                              67.265.11
# 35                         Body: H. 18 7/8 in. (47.9 cm)
# 36     Cover: 4 1/4 x 4 13/16 in. (10.8 x 12.2 cm); 1...
# 256                 Ring pull: Diam. 3 1/4 in. (8.3 cm)"
# 258                 Ring pull: Diam. 2 1/4 in. (5.7 cm)"
# 260                 Ring pull: Diam. 1 7/8 in. (4.8 cm)"
# 462    ,H. 6 in. (15.2 cm),Friends of the American Wi...
# 1436                       Shade: Dimension unavailable"
# 1438                      Shade: Dimensions unavailable"
# 1508                                          white pine
# 1512                                 with yellow poplar"
# ...

# %% [markdown]
# #### Apply

# %%
#applying the describe function
#summary stats over departments
df_by_department.describe().head()
# Out:
#                                               Object Number         \
#                                                       count unique
# Department
#  1954"                                                    3      3
#  glass with                                               1      1
#  white pine"                                              1      1
# 36 x 49 1/2 x 22 in. (91.4 x 125.7 x 55.9 cm)             1      1
# American                                                  1      1
#
#                                                                                                   \
#                                                                                              top
# Department
#  1954"                                         ,9 5/8 x 13 5/8 in. (24.4 x 34.6 cm),The Edwar...
#  glass with                                                                                gesso
# ...

# %% [markdown]
# #### Combine

# %%
#getting the count for number of values in each column for each department group
#combining into a new dataframe
df_count_by_department = df_by_department.count()
df_count_by_department.head()
# Out:
#                                                Object Number  Is Highlight  \
# Department
#  1954"                                                     3             3
#  glass with                                                1             1
#  white pine"                                               1             1
# 36 x 49 1/2 x 22 in. (91.4 x 125.7 x 55.9 cm)              1             1
# American                                                   1             1
#
#                                                Is Public Domain  Object ID  \
# Department
#  1954"                                                        3          3
#  glass with                                                   1          1
#  white pine"                                                  1          1
# 36 x 49 1/2 x 22 in. (91.4 x 125.7 x 55.9 cm)                 1          1
# American                                                      0          1
#
# ...

# %% [markdown]
# # Cross Tabs

# %%
#summarize the data by object classification and culture
pd.crosstab([met_objects['Classification']],met_objects['Culture'],margins=True)
# Out:
# Culture                   American  American or British  American or Canadian  \
# Classification
# Architecture                   123                    0                     0
# Ceramics                       789                    0                     0
# Drawings                       639                    0                     0
# Frames                           8                    1                     0
# Furniture                     1102                   16                     0
# Glass                         1822                   68                     0
# Gold                             1                    0                     0
# Jewelry                         41                    0                     0
# Metal                          513                   18                     1
# Metalwork-Brass                  0                    0                     0
# Metalwork-Pewter                 0                    0                     0
# ...

# %% [markdown]
# # Converting Between String and Datetime

# %%
#convert dates in table to actual date time format --> they were previously object types
#errors = 'coerce' will mark any invalid dates as NaT
#convert not parseable values to string
met_objects['Artist Begin Date'] =  pd.to_datetime(met_objects['Artist Begin Date'].astype(str),errors='coerce')

# %%
met_objects['Artist End Date'] =  pd.to_datetime(met_objects['Artist End Date'].astype(str),errors='coerce')

# %%
met_objects['Object Date'] =  pd.to_datetime(met_objects['Object Date'],errors='coerce')

# %%
met_objects['Object Begin Date'] =  pd.to_datetime(met_objects['Object Begin Date'],errors='coerce')

# %%
met_objects['Object End Date'] =  pd.to_datetime(met_objects['Object End Date'],errors='coerce')

# %%
met_objects['Metadata Date'] =  pd.to_datetime(met_objects['Metadata Date'],errors='coerce')

# %%
met_objects.dtypes
# Out:
# Object Number                           object
# Is Highlight                            object
# Is Public Domain                        object
# Object ID                               object
# Department                              object
# Object Name                             object
# Title                                   object
# Culture                                 object
# Period                                  object
# Dynasty                                 object
# Reign                                   object
# Portfolio                               object
# Artist Role                             object
# Artist Prefix                           object
# Artist Display Name                     object
# Artist Display Bio                      object
# Artist Suffix                           object
# Artist Alpha Sort                       object
# Artist Nationality                      object
# Artist Begin Date                       object
# ...

# %% [markdown]
# # Date Offsets

# %%
#finding the Monday or next Monday for each start date --> start of the week
#if the Object Begin Date is already a Monday, the new column will have the same value
#if not, it will find the date for the next Monday
met_objects['mondayDate'] = met_objects['Object Begin Date'].apply(lambda x: x + pd.DateOffset(days=7-x.weekday()) if  x.weekday() else x)

# %%
met_objects['mondayDate']
# Out:
# 0       1853-01-03
# 1       1901-01-07
# 2       1909-01-04
# 3       1909-01-04
# 4       1909-01-04
#            ...
# 12103   1911-01-02
# 12104   1909-01-04
# 12105   1898-01-03
# 12106   1950-01-02
# 12107          NaT
# Name: mondayDate, Length: 11922, dtype: datetime64[ns]

# %% [markdown]
# # Generating Date Ranges

# %% [markdown]
# #### This code was taking too long to run

# %%
#new column for object date range
#met_objects['Object_Date_Range'] = met_objects.apply(lambda x: list(pd.date_range(met_objects['Object Begin Date'].min(),met_objects['Object End Date'].max())),axis=1)
